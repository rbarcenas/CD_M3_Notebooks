# %% [markdown]
# # Distribuciones de probabilidad con Python
#
# ### Elaborado por: Dr. Roberto Bárcenas
#
# Una forma de representar a las distribuciones discretas es utilizando su Función de Masa de Probabilidad o FMP. Veamos algunas distribuciones discretas.
#
# ## Binomial
#
# La Distribución Binomial esta dada por la formula:
#
# $$
# p(r; N, p) = \left(\begin{array}{c} N \\ r \end{array}\right) p^r(1 - p)^{N - r}
# $$
#
# donde $0 \leq p \leq 1$.  La Distribución Binomial describe la probabilidad de tener exactamente $r$ éxitos en $N$ realizaciones si la probabilidad de éxito (en una sola prueba) es $p$.
#
# El siguiente ejemplo declara $X \sim \text{Bin}(n = 10, p = 0.2)$

# %%
# !pip install scipy

# %%
from scipy import stats
from scipy import special
import numpy as np
import matplotlib.pyplot as plt

# %%
X = stats.binom(10, 0.2) # Declara X  una varianle aleatoria binomial 

#help(X)

X = stats.binom(10, 0.2) # Declara X como una binomial (n=10,p=0.2)
print(X.pmf(3))           # P(X = 3)
print(X.cdf(4))           # P(X <= 4)
print(X.ppf(0.95))

print(X.mean())           # E[X]
print(X.var())            # Var(X)
print(X.std())            # Std(X)
print(X.rvs())            # Un punto aleatorio con distrinbucion X
print(X.rvs(10))          # Genera una muestra de tamaño 10 con distribucion X
# Out:
# 0.20132659199999992
# 0.9672065024
# 4.0
# 2.0
# 1.6
# 1.2649110640673518
# 3
# [4 2 1 0 3 3 5 1 0 0]

# %%
# Graficando una distrinbucion Binomial
N, p = 30, 0.4 # parametros de forma 
binomial = stats.binom(N, p) # Distribución
x = np.arange(binomial.ppf(0.01),
              binomial.ppf(0.99))

fmp = binomial.pmf(x) # Función de Masa de Probabilidad
#plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Binomial')
plt.ylabel('Funcion de probabilidad')
plt.xlabel('X')
plt.show()

# %%
# Graficando Función de Distribución Acumulada con Python

n, p = 30, 0.4 # parametros de forma de la distribución binomial
fda_binom = stats.binom.cdf(x, n, p) # Función de Distribución Acumulada
plt.plot(x, fda_binom, '--', label='FDA binomial')
plt.title('Función de Distribución Acumulada')
plt.ylabel('F(x)')
plt.xlabel('x')
plt.legend(loc=4)
plt.show()

# %%
# Creacion de un histograma
binom_sim = binomial.rvs(1000)  # genera 1000 numeros aleatorios
plt.hist(binom_sim, bins=10)
plt.ylabel('Frecuencia')
plt.xlabel('X')
plt.title('Histograma Binomial')
plt.show()

# %% [markdown]
# # Distribucion Normal
#
# La Distribución Normal o Gaussiana, es aplicable a un amplio rango de problemas y es la distribución más utilizada en estadística. Su función de densidad esta dada por la formula:
#
# $$
# \phi(x;\mu, \sigma^2) = \frac{1}{\sigma \sqrt{2 \pi}} e^{\frac{-1}{2}\left(\frac{x - \mu}{\sigma} \right)^2}
# $$
#
# Por ejemplo, a continuación se declara una variable aleatoria $X \sim N(\mu=3,\sigma^2=16)$. Luego, calculamos $f_{X}(x)$ y $F_{X}(x)$. Nota: verificar de acuerdo al módulo utilizado si el segundo parámetro de una Normal es la varianza $\sigma^2$. Por ejemplo, en scipy el segundo parámetro es la desviación estándar.

# %%
import math
from scipy import stats
A = stats.norm(3, math.sqrt(16)) # Declare X ~ N(3,16)
print(A.pdf(4))       # f(3), la densidad en 3
print(A.cdf(2))       # F(2), la distribucion P(Y < 2)
print(A.rvs())        # un aleatorio de X
# Out:
# 0.09666702920071232
# 0.4012936743170763
# -2.4562394652302686

# %%
# Graficando la densidad Normal

mu, sigma = 0, 0.2 # media y desviacion estandar
normal = stats.norm(mu, sigma)
#x = np.linspace(normal.ppf(0.0001),
#                normal.ppf(0.9999), 1000)
x = np.linspace(-1,1, 100)
fp = normal.pdf(x) # Función de Probabilidad
plt.plot(x, fp)
plt.title('Densidad Normal')
plt.ylabel('f(x)')
plt.xlabel('x')
plt.show()

# %%
mu, sigma =0, 0.2 # media y desviacion estandar parametros de localizacion y escala de la distribución Normal
fda_norma = stats.norm.cdf(x, mu, sigma) # Función de Distribución Acumulada
plt.plot(x, fda_binom, '--', label='FDA Normal')
plt.title('Función de Distribución Acumulada')
plt.ylabel('F(x)')
plt.xlabel('x')
plt.legend(loc=4)
plt.show()

# %%
# Histograma de valores de una Normal
aleatorios = normal.rvs(1000) # genera aleatorios
cuenta, cajas, ignorar = plt.hist(aleatorios, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Normal')
plt.show()

# %% [markdown]
# Referencias:
#
# https://docs.scipy.org/doc/scipy/reference/stats.html#module-scipy.stats
#
# https://github.com/yulingl/cs109_python_tutorial/blob/master/cs109_python_tutorial.ipynb
#
# https://relopezbriega.github.io/blog/2016/06/29/distribuciones-de-probabilidad-con-python/
